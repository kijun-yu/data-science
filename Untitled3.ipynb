# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
x = df["Happiness.Rank"]
y = df["Happiness.Score"]
plt.scatter(x, y)

# %%
kcj = df[df["Country"].isin(["South Korea", "China", "Japan"])]

# %%
kcj
# Out:
#         Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 50        Japan              51            5.920      5.990719     5.849281
# 54  South Korea              55            5.838      5.922559     5.753441
# 78        China              79            5.273      5.319278     5.226721
#
#     Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 50                  1.416915  1.436338                  0.913476  0.505626
# 54                  1.401678  1.128274                  0.900214  0.257922
# 78                  1.081166  1.160837                  0.741416  0.472788
#
#     Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 50    0.120573                       0.163761           1.363224
# 54    0.206674                       0.063283           1.880378
# 78    0.028807                       0.022794           1.764939

# %%
plt.bar(kcj["Country"], kcj["Happiness.Score"])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.scatter(df["Economy..GDP.per.Capita."],df["Health..Life.Expectancy."] )

# %%
top10 = df.iloc[0:10, :]

# %%
top10
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
# 5  Netherlands               6            7.377      7.427426     7.326574
# 6       Canada               7            7.316      7.384403     7.247597
# 7  New Zealand               8            7.314      7.379510     7.248490
# 8       Sweden               9            7.284      7.344095     7.223905
# 9    Australia              10            7.284      7.356651     7.211349
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# ...

# %%
btom10 = df.iloc[-10:, :]

# %%
btom10
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 145                     Yemen             146            3.593      3.692750
# 146               South Sudan             147            3.591      3.725539
# 147                   Liberia             148            3.533      3.653756
# 148                    Guinea             149            3.507      3.584428
# 149                      Togo             150            3.495      3.594038
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 145     3.493250                  0.591683  0.935382
# ...

# %%
top10.describe().mean()
# Out:
# Happiness.Rank                   5.753456
# Happiness.Score                  6.821869
# Whisker.high                     6.873587
# Whisker.low                      6.770351
# Economy..GDP.per.Capita.         2.380127
# Family                           2.396130
# Health..Life.Expectancy.         1.870259
# Freedom                          1.712774
# Generosity                       1.559199
# Trust..Government.Corruption.    1.496305
# Dystopia.Residual                2.942540
# dtype: float64

# %%
btom10.describe().mean()
# Out:
# Happiness.Rank                   114.503456
# Happiness.Score                    3.792545
# Whisker.high                       3.886905
# Whisker.low                        3.705815
# Economy..GDP.per.Capita.           1.541168
# Family                             1.766477
# Health..Life.Expectancy.           1.454385
# Freedom                            1.491482
# Generosity                         1.467199
# Trust..Government.Corruption.      1.375396
# Dystopia.Residual                  2.387888
# dtype: float64

# %%
df.corr()
# Out:
# C:\Users\kijun\AppData\Local\Temp\ipykernel_23460\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                Happiness.Rank  Happiness.Score  Whisker.high  \
# Happiness.Rank                       1.000000        -0.992774     -0.993058
# Happiness.Score                     -0.992774         1.000000      0.999497
# Whisker.high                        -0.993058         0.999497      1.000000
# Whisker.low                         -0.991533         0.999520      0.998036
# Economy..GDP.per.Capita.            -0.813244         0.812469      0.811868
# Family                              -0.736753         0.752737      0.750934
# Health..Life.Expectancy.            -0.780716         0.781951      0.776634
# ...

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\kijun\AppData\Local\Temp\ipykernel_23460\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >
