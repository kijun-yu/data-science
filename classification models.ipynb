# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris

from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score

# %%
iris_data = load_iris()

# %%
iris_data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
print(iris_data["feature_names"])
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
iris_df = pd.DataFrame(data = iris_data["data"], columns = iris_data["feature_names"])

# %%
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
X = iris_df
Y = iris_data["target"]

# %%
Y.shape
# Out:
# (150,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.3, random_state = 3)

X_train.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 51                 6.4               3.2                4.5               1.5
# 23                 5.1               3.3                1.7               0.5
# 83                 6.0               2.7                5.1               1.6
# 142                5.8               2.7                5.1               1.9
# 84                 5.4               3.0                4.5               1.5

# %%
X_train.shape
# Out:
# (105, 4)

# %%
X_test.shape
# Out:
# (45, 4)

# %%
Y_train.shape
# Out:
# (105,)

# %%
Y_test.shape
# Out:
# (45,)

# %%
iris_df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %%
iris_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
iris_df[iris_df.duplicated()]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 142                5.8               2.7                5.1               1.9

# %%
iris_df.loc[(iris_df["sepal length (cm)"] == 5.8) & (iris_df["petal length (cm)"] == 5.1)]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 101                5.8               2.7                5.1               1.9
# 114                5.8               2.8                5.1               2.4
# 142                5.8               2.7                5.1               1.9

# %%
df = iris_df.drop_duplicates()

# %%
df.iloc[141]
# Out:
# sepal length (cm)    6.9
# sepal width (cm)     3.1
# petal length (cm)    5.1
# petal width (cm)     2.3
# Name: 141, dtype: float64

# %%
df.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.118129           0.873738
# sepal width (cm)           -0.118129          1.000000          -0.426028
# petal length (cm)           0.873738         -0.426028           1.000000
# petal width (cm)            0.820620         -0.362894           0.962772
#
#                    petal width (cm)
# sepal length (cm)          0.820620
# sepal width (cm)          -0.362894
# petal length (cm)          0.962772
# petal width (cm)           1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(data = df.corr(), square = True, annot = True, cbar = True)
plt.show()

# %%
iris_df = pd.DataFrame(data = iris_data["data"], columns = iris_data["feature_names"])

# %%
iris_df["target"] = iris_data["target"]

# %%
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
df = iris_df.drop_duplicates()

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
df["target"].value_counts()
# Out:
# 0    50
# 1    50
# 2    49
# Name: target, dtype: int64

# %%
plt.hist(x = 'petal length (cm)', data = df)
plt.show()

# %%
sns.displot(x = "petal length (cm)", kind = "kde", data = df, hue = "target")

# %%
sns.pairplot(df, hue = "target", height = 3, diag_kind= "kde")
plt.show()
